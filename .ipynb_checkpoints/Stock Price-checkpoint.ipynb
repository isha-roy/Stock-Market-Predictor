# %%
pip install yfinance
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: yfinance in c:\users\isha\appdata\roaming\python\python312\site-packages (0.2.40)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\isha\appdata\roaming\python\python312\site-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\isha\appdata\roaming\python\python312\site-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in c:\users\isha\appdata\roaming\python\python312\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\isha\appdata\roaming\python\python312\site-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in c:\users\isha\appdata\roaming\python\python312\site-packages (from yfinance) (5.2.2)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\isha\appdata\roaming\python\python312\site-packages (from yfinance) (4.2.2)
# Requirement already satisfied: pytz>=2022.5 in c:\users\isha\appdata\roaming\python\python312\site-packages (from yfinance) (2024.1)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\isha\appdata\roaming\python\python312\site-packages (from yfinance) (2.4.4)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\isha\appdata\roaming\python\python312\site-packages (from yfinance) (3.17.5)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\isha\appdata\roaming\python\python312\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in c:\users\isha\appdata\roaming\python\python312\site-packages (from yfinance) (1.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\isha\appdata\roaming\python\python312\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: six>=1.9 in c:\users\isha\appdata\roaming\python\python312\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\isha\appdata\roaming\python\python312\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\isha\appdata\roaming\python\python312\site-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\isha\appdata\roaming\python\python312\site-packages (from pandas>=1.3.0->yfinance) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\isha\appdata\roaming\python\python312\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\isha\appdata\roaming\python\python312\site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\isha\appdata\roaming\python\python312\site-packages (from requests>=2.31->yfinance) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\isha\appdata\roaming\python\python312\site-packages (from requests>=2.31->yfinance) (2024.6.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf

# %%
from datetime import datetime
end = datetime.now()
start= datetime(end.year-20,end.month,end.day)

# %%
stock = 'NFLX'
google_data = yf.download(stock, start, end)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
google_data.head()
# Out:
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 2004-06-28  4.610000  5.000000  4.574286  4.857143   4.857143  30273600
# 2004-06-29  4.978571  5.037143  4.865714  4.882857   4.882857  15225700
# 2004-06-30  5.080000  5.224286  4.980000  5.142857   5.142857  29511300
# 2004-07-01  5.100000  5.152857  5.055714  5.135714   5.135714  23076200
# 2004-07-02  4.970000  4.970000  4.557143  4.615714   4.615714  33603500

# %%
google_data.shape
# Out:
# (5035, 6)

# %%
google_data.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  5035.000000  5035.000000  5035.000000  5035.000000  5035.000000
# mean    157.257000   159.638166   154.819748   157.297822   157.297822
# std     188.382198   190.984915   185.678310   188.392548   188.392548
# min       1.300000     1.317143     1.272857     1.290000     1.290000
# 25%       6.153571     6.281429     6.041428     6.168571     6.168571
# 50%      55.342857    56.502857    54.544285    55.531429    55.531429
# 75%     309.854996   315.650009   304.200012   310.370010   310.370010
# max     692.349976   700.989990   686.090027   691.690002   691.690002
#
#              Volume
# count  5.035000e+03
# mean   1.567820e+07
# std    1.871515e+07
# min    2.651780e+05
# 25%    5.806300e+06
# 50%    9.705900e+06
# 75%    1.845580e+07
# max    3.234140e+08

# %%
google_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 5035 entries, 2004-06-28 to 2024-06-27
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       5035 non-null   float64
#  1   High       5035 non-null   float64
#  2   Low        5035 non-null   float64
#  3   Close      5035 non-null   float64
#  4   Adj Close  5035 non-null   float64
#  5   Volume     5035 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 275.4 KB

# %%
google_data.isna().sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib  inline

# %%
plt.figure(figsize=(15,5))
google_data['Adj Close'].plot()
plt.xlabel("years")
plt.ylabel("Adj Close")
plt.title("Closing price of Netflix Data")
# Out:
# Text(0.5, 1.0, 'Closing price of Netflix Data')

# %%
def plot_graph(figsize, values, column_name):
    plt.figure(figsize= figsize)
    values.plot()
    plt.xlabel("years")
    plt.ylabel(column_name)
    plt.title(f"{column_name} of Netflix Data")

# %%
google_data.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
for column in google_data.columns:
    plot_graph((15,5),google_data[column], column)

# %%
for i in range(2004,2025):
    print(i,list(google_data.index.year).count(i))
# Out:
# 2004 131
# 2005 252
# 2006 251
# 2007 251
# 2008 253
# 2009 252
# 2010 252
# 2011 252
# 2012 250
# 2013 252
# 2014 252
# 2015 252
# 2016 252
# 2017 251
# 2018 251
# 2019 252
# 2020 253
# 2021 252
# 2022 251
# 2023 250
# 2024 123

# %%
google_data ['MA_for_250_days']=google_data['Adj Close'].rolling(250).mean()

# %%
google_data['MA_for_250_days'][0:250].tail()
# Out:
# Date
# 2005-06-16         NaN
# 2005-06-17         NaN
# 2005-06-20         NaN
# 2005-06-21         NaN
# 2005-06-22    2.036303
# Name: MA_for_250_days, dtype: float64

# %%
plot_graph((15,5),google_data['MA_for_250_days'],'MA_for_250_days')

# %%
plot_graph((15,5),google_data[['Adj Close','MA_for_250_days']],'MA_for_250_days')

# %%
google_data ['MA_for_100_days']=google_data['Adj Close'].rolling(100).mean()
plot_graph((15,5),google_data[['Adj Close','MA_for_100_days']],'MA_for_100_days')

# %%
plot_graph((15,5),google_data[['Adj Close','MA_for_100_days','MA_for_250_days']],'MA')

# %%
google_data['percentage_change_cp'] = google_data['Adj Close'].pct_change()
google_data[['Adj Close','percentage_change_cp']].head()
# Out:
#             Adj Close  percentage_change_cp
# Date
# 2004-06-28   4.857143                   NaN
# 2004-06-29   4.882857              0.005294
# 2004-06-30   5.142857              0.053248
# 2004-07-01   5.135714             -0.001389
# 2004-07-02   4.615714             -0.101252

# %%
plot_graph((15,5),google_data['percentage_change_cp'],'percentage_change_cp')

# %%
Adj_close_price = google_data[['Adj Close']]

# %%
max(Adj_close_price.values),min(Adj_close_price.values)
# Out:
# (array([691.69000244]), array([1.28999996]))

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(Adj_close_price)
scaled_data
# Out:
# array([[0.00516678],
#        [0.00520402],
#        [0.00558062],
#        ...,
#        [0.97207412],
#        [0.9797219 ],
#        [0.99236672]])

# %%
len(scaled_data)
# Out:
# 5035

# %%
x_data = []
y_data = []

for i in range(100, len(scaled_data)):
    x_data.append(scaled_data[i-100:i])
    y_data.append(scaled_data[i])
    
import numpy as np
x_data, y_data = np.array(x_data), np.array(y_data)

# %%
x_data[0],y_data[0]
# Out:
# (array([[5.16677716e-03],
#         [5.20402212e-03],
#         [5.58061573e-03],
#         [5.57026952e-03],
#         [4.81708299e-03],
#         [5.06745496e-03],
#         [5.03227993e-03],
#         [4.73431473e-03],
#         [5.04883248e-03],
#         [4.87295182e-03],
#         [4.71983073e-03],
#         [4.76535335e-03],
#         [4.75293859e-03],
#         [2.89480144e-03],
#         [2.30508255e-03],
#         [2.59269982e-03],
#         [2.26990579e-03],
#         [2.31956689e-03],
#         [2.32577358e-03],
#         [2.07540126e-03],
#         [2.34439606e-03],
#         [2.31749730e-03],
#         [2.33198165e-03],
#         [2.37336474e-03],
#         [2.30301296e-03],
#         [2.11471615e-03],
#         [1.75881530e-03],
#         [1.66983931e-03],
#         [1.63052442e-03],
#         [1.52913402e-03],
#         [1.67811559e-03],
#         [1.46498996e-03],
#         [1.31393846e-03],
#         [1.23117054e-03],
#         [1.31393846e-03],
#         [1.35325335e-03],
#         [1.38842838e-03],
#         [1.41119072e-03],
#         [1.40912079e-03],
#         [1.42360514e-03],
#         [1.33049101e-03],
#         [1.37394404e-03],
#         [1.28496977e-03],
#         [1.26634695e-03],
#         [1.12150352e-03],
#         [1.01804319e-03],
#         [1.08425683e-03],
#         [1.20427144e-03],
#         [1.10288104e-03],
#         [1.32014618e-03],
#         [1.24979302e-03],
#         [1.25186261e-03],
#         [1.22289392e-03],
#         [1.40498266e-03],
#         [1.50844299e-03],
#         [1.42153693e-03],
#         [1.66777076e-03],
#         [1.64707869e-03],
#         [1.80640647e-03],
#         [1.75467717e-03],
#         [1.61811001e-03],
#         [1.60776380e-03],
#         [1.57672518e-03],
#         [1.51258113e-03],
#         [1.52292733e-03],
#         [1.52085740e-03],
#         [1.32221473e-03],
#         [1.51051119e-03],
#         [1.70087793e-03],
#         [1.86641239e-03],
#         [1.84572136e-03],
#         [1.76088351e-03],
#         [1.59948718e-03],
#         [1.73812289e-03],
#         [1.70708427e-03],
#         [1.72156862e-03],
#         [1.73812289e-03],
#         [2.62788279e-04],
#         [1.73812289e-04],
#         [1.86226873e-04],
#         [2.21403628e-04],
#         [2.15195559e-04],
#         [1.59327946e-04],
#         [1.98642838e-04],
#         [1.20013054e-04],
#         [1.34497397e-04],
#         [1.15874917e-04],
#         [9.10443679e-05],
#         [8.27680938e-05],
#         [1.82088736e-04],
#         [2.25541765e-04],
#         [3.18655892e-04],
#         [3.91077607e-04],
#         [3.78663196e-04],
#         [3.37278372e-04],
#         [2.79341000e-04],
#         [3.55901025e-04],
#         [3.78663196e-04],
#         [4.55223048e-04],
#         [3.70385368e-04]]),
#  array([0.0002959]))

# %%
int(len(x_data)*0.7)
# Out:
# 3454

# %%
4908-100-int(len(x_data)*0.7)
# Out:
# 1354

# %%
splitting_len = int(len(x_data)*0.7)
x_train = x_data[:splitting_len]
y_train = y_data[:splitting_len]

x_test = x_data[splitting_len:]
y_test = y_data[splitting_len:]

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (3454, 100, 1)
# (3454, 1)
# (1481, 100, 1)
# (1481, 1)

# %%
from keras.models import Sequential
from keras.layers import Dense, LSTM

# %%
model = Sequential()
model.add(LSTM(128, return_sequences=True, input_shape=(x_train.shape[1],1)))
model.add(LSTM(64,return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))
# Out:
# C:\Users\Isha\AppData\Roaming\Python\Python312\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
model.fit(x_train, y_train, batch_size=1, epochs = 2)
# Out:
# Epoch 1/2
# 3454/3454 ━━━━━━━━━━━━━━━━━━━━ 232s 67ms/step - loss: 7.8786e-04
# Epoch 2/2
# 3454/3454 ━━━━━━━━━━━━━━━━━━━━ 151s 44ms/step - loss: 2.8305e-04

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 100, 128)            │          66,560 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 64)                  │          49,408 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 25)                  │           1,625 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │              26 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 352,859 (1.35 MB)
#  Trainable params: 117,619 (459.45 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 235,240 (918.91 KB)

# %%
predictions = model.predict(x_test)
# Out:
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 3s 56ms/step

# %%
predictions
# Out:
# array([[0.49581596],
#        [0.49683157],
#        [0.49762928],
#        ...,
#        [0.9433898 ],
#        [0.9404648 ],
#        [0.94041413]], dtype=float32)

# %%
inv_predictions = scaler.inverse_transform(predictions)
inv_predictions
# Out:
# array([[343.60135],
#        [344.30252],
#        [344.85327],
#        ...,
#        [652.6063 ],
#        [650.5869 ],
#        [650.55194]], dtype=float32)

# %%
inv_y_test = scaler.inverse_transform(y_test)
inv_y_test
# Out:
# array([[347.60998535],
#        [349.35998535],
#        [345.86999512],
#        ...,
#        [672.40997314],
#        [677.69000244],
#        [686.41998291]])

# %%
rmse = np.sqrt(np.mean( (inv_predictions - inv_y_test)**2))

# %%
rmse
# Out:
# 17.990996715810972

# %%
import pandas as pd
ploting_data = pd.DataFrame(
 {
  'original_test_data': inv_y_test.reshape(-1),
    'predictions': inv_predictions.reshape(-1)
 } ,
    index = google_data.index[splitting_len+100:]
)
ploting_data.head()
# Out:
#             original_test_data  predictions
# Date
# 2018-08-08          347.609985   343.601349
# 2018-08-09          349.359985   344.302521
# 2018-08-10          345.869995   344.853271
# 2018-08-13          341.309998   344.265076
# 2018-08-14          337.489990   342.286926

# %%
plot_graph((15,6), ploting_data, 'test data')

# %%
plot_graph((15,6), pd.concat([Adj_close_price[:splitting_len+100],ploting_data], axis=0), 'whole data')

# %%
model.save("Latest_stock_price_model.keras")
